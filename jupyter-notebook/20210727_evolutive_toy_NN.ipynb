# %%
from datetime import datetime
import os, pickle

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import torch
from torch import nn, optim
import torch.nn.functional as F
from torch.utils.data import DataLoader
from torchvision import datasets
from torchvision.transforms import ToTensor

from torchinfo import summary

# %%
dataset_path = os.path.realpath('D:\\Python\\DL_test\\datasets')


training_data = datasets.MNIST(
    root=dataset_path,
    train=True,
    download=True,
    transform=ToTensor(),
)
test_data = datasets.MNIST(
    root=dataset_path,
    train=False,
    download=True,
    transform=ToTensor(),
)

batch_size = 64

# Create data loaders.
train_dataloader = DataLoader(training_data, batch_size=batch_size, shuffle=True)
test_dataloader = DataLoader(test_data, batch_size=batch_size)

for X, y in train_dataloader:
    print("Shape of X [N, C, H, W]: ", X.shape, X.dtype)
    print("Shape of y: ", y.shape, y.dtype)
    break
# Out:
# Shape of X [N, C, H, W]:  torch.Size([64, 1, 28, 28]) torch.float32
# Shape of y:  torch.Size([64]) torch.int64

# %%
class TestNN(nn.Module):
    def __init__(self, layers_dict):
        super().__init__()
        self.layers_dict_in = layers_dict
        self.layers_dict = nn.ModuleDict({name: value["fun"](*value["dims"], name) 
                                          for name, value in self.layers_dict_in.items()})
        self.historique = pd.DataFrame()
            
        return
        
    def forward(self, x):
        for _, layer in self.layers_dict.items():
            x = layer(x)
        return x

# %%
class ResBlock(nn.Module):
    def __init__(self, dim_in, dim_inter, dim_out, nom):
        super(ResBlock, self).__init__()
        self.dim_out = dim_out
#         
        self.repeat = int(np.ceil(dim_out/dim_in))
        self.layers_dict = nn.ModuleDict({
            f"{nom}_conv2d_0": nn.Conv2d(in_channels=dim_in, out_channels=dim_inter, kernel_size=3, 
                      stride=1, padding=1, dilation=1, groups=1, bias=True, 
                      padding_mode='zeros'), 
            f"{nom}_activation": nn.LeakyReLU(negative_slope=0.2, inplace=False),
            f"{nom}_conv2d_1": nn.Conv2d(in_channels=dim_inter, out_channels=dim_out, kernel_size=3, 
                      stride=1, padding=1, dilation=1, groups=1, bias=True, 
                      padding_mode='zeros'), 
            })

        return
    
    def forward(self, x):
        input = torch.tile(x=x, dims=(1, self.repeat, 1, 1))
        input = input[:, :self.dim_out, :, :]
        for _, layer in self.layers_dict.items():
#             print(f"x.shape : {x.shape}")
            x = layer(x)
#         print(f"input.shape : {input.shape}")
#         print(f"x.shape : {x.shape}")
        x = (input + x)
        return x


class DenseBlock(nn.Module):
    def __init__(self, dim_in, dim_out, nom):
        super(DenseBlock, self).__init__()
        self.layers_dict = nn.ModuleDict({
            f"{nom}_Flatten": nn.Flatten(), 
            f"{nom}_Dense": nn.Linear(dim_in, dim_out),
            })

        return
    
    def forward(self, x):
        for _, layer in self.layers_dict.items():
#             print(f"x.shape : {x.shape}")
            x = layer(x)
        x = nn.functional.log_softmax(x, dim=1)
        return x

    
class DownscaleBlock(nn.Module):
    def __init__(self, nom):
        super(DownscaleBlock, self).__init__()
        self.layers_dict = nn.ModuleDict({
            f"{nom}_MaxPool2d": nn.MaxPool2d(kernel_size=2, stride=2, 
                                  padding=0, dilation=1),
            })
        return
    
    def forward(self, x):
        for _, layer in self.layers_dict.items():
            x = layer(x)
            return x

# %%
class ModelsMgmt():
    def load(self, model, device, path, model_name):

        try:
            with open(os.path.join(path, f"{model_name}_layers_dict_in.pk"), "rb") as f:
                layers_dict_in = pickle.load(f)
        except:
            print('unable to load layers_dict')

        model.__init__(layers_dict_in)
        model.load_state_dict(torch.load(os.path.join(path, f"{model_name}_params.pt")))
        
        try:
            model.historique = pd.read_excel(os.path.join(path, f"{model_name}_historique.xlsx"), index_col=0)
        except:
            print('unable to load historique')
            
        model.to(device)
        
        return
    
    def save(self, model, path, model_name):
        
        if not os.path.exists(path):
            os.makedirs(path)
        with open(os.path.join(path, f"{model_name}_layers_dict_in.pk"), "wb") as f:
            pickle.dump(model.layers_dict_in, f)      
            
        torch.save(model.state_dict(), os.path.join(path, f"{model_name}_params.pt"))
        
        if len(model.historique)!=0:
            model.historique.to_excel(os.path.join(path, f"{model_name}_historique.xlsx"))
        return
    
    def optimize_layers(self, model, device, tresh_prun, tresh_add, flatten_size):
        '''Pseudocode : 
        On balaye les couches. 
        Lorsque s[-1]/energy est inférieur à treshold_inf, diminue la sortie de 1.
        Lorsque s[-1]/energy est supérieur à treshold_sup, on augmente la sortie de 1.
        On sauve et on actualise l'historique
        '''
        blocks = [key.split('.')[-2] for key in model.state_dict()
                 if key.split('.')[-1] == 'weight']
        if len(model.historique) == 0:
            columns = [f"{block}_s" for block in blocks]
            columns += [f"{block}_dims" for block in blocks]
            model.historique = pd.DataFrame(columns=columns).astype('object')
        curr_idx = datetime.now().strftime("%y-%m-%d-%H:%M:%S")
        model.historique.append(pd.Series(name=curr_idx, dtype='object'))
        curr_block = ""
        layer_in_block = 0
        new_state_dict = {}
        evol_dim_in=0
        for param_tensor in model.state_dict():
            if param_tensor[-6:]=="weight" :
                layer_tree = param_tensor.split(".")
                block = layer_tree[1]
                curr_layer = layer_tree[-2]
                print(f"curr_layer : {curr_layer}")
                if block == curr_block:
                    layer_in_block += 1
                else:
                    layer_in_block = 0
                    curr_block = block
                weight = model.state_dict()[param_tensor]
                u, s, vh = get_usvh(weight)
                model.historique.at[curr_idx, f"{curr_layer}_s"] = str(s.tolist())
                model.historique.at[curr_idx, f"{curr_layer}_dims"] = str(weight.shape[:2])
                if len(weight.shape)==4:
                    in_step = 1
                else:
                    in_step = flatten_size**2

                if evol_dim_in <0:
                    print(f"réduire d_in de {evol_dim_in * in_step}")
                elif evol_dim_in == 1:
                    print(f"augmenter d_in de {evol_dim_in * in_step}")
                model.layers_dict_in[block]["dims"][layer_in_block] = weight.shape[1] + in_step * evol_dim_in

                energy = torch.sum(s)
                print(f"s[-1]/energy : {s[-1]/energy}")
                if (s[-1] < tresh_prun*energy) and (curr_layer != blocks[-1]):
                    i = 1
                    while torch.sum(s[-i-1:]) < tresh_prun*energy:
                        i += 1
                    print(f"réduire d_out de {i}")
                    evol_dim_out = -i
                elif (s[-1] > tresh_add*energy) and (curr_layer != blocks[-1]):
                    print("augmenter d_out de 1")
                    evol_dim_out = 1
                else:
                    evol_dim_out = 0
                
                # update wieghts and bias
                param_bias = param_tensor[:-6]+"bias"
                bias = model.state_dict()[param_bias]
                if evol_dim_in != 0 or evol_dim_out != 0 :
                    weight, evol_dim_in, evol_dim_out = update_weight(m=weight, u=u, s=s, vh=vh, evol_dim_in=evol_dim_in * in_step, 
                                                                      evol_dim_out=evol_dim_out, device=device)
                    bias = update_bias(bias, evol_dim_out, device)
                
                    print(f"weight.shape : {weight.shape}")
                    print(f"bias.shape : {bias.shape}")
                    print(f"evol_dim_out : {evol_dim_out}")
                new_state_dict[param_tensor] = weight
                new_state_dict[param_bias] = bias
                
                model.layers_dict_in[block]["dims"][layer_in_block + 1] += evol_dim_out
                
                evol_dim_in = evol_dim_out
            else:
                if param_tensor not in new_state_dict.keys():
                    new_state_dict[param_tensor] = model.state_dict[param_tensor]


        generic_name = "tmp"
        model.layers_dict = nn.ModuleDict({name: value["fun"](*value["dims"], name) 
                                          for name, value in model.layers_dict_in.items()})
        model.load_state_dict(new_state_dict)
        self.save(model, "D:\\Python\\DL_test\\DL_tests\\bckup", f"{generic_name}")
        self.load(model, device, "D:\\Python\\DL_test\\DL_tests\\bckup", f"{generic_name}")
        print(f"layers_dict_in : {model.layers_dict_in}")

        return model

# %%
def get_usvh(m):
    if len(m.shape)==4:
        # Format d_out * d_in ou ch_out * ch_in * h * w
        # la dimension coupée doit être la première du reshape/slice
        a = m.reshape(m.shape[0], m.shape[1]*m.shape[2]*m.shape[3])
        d_in = m.shape[1]*m.shape[2]*m.shape[3]
        d_out = m.shape[0]

    elif len(m.shape)==2:
        a = m
        d_in = m.shape[1]
        d_out = m.shape[0]

    u, s, vh = torch.linalg.svd(a, full_matrices=False)
    print(f"s : {s[0]}...{s[-1]}, s.shape : {s.shape}")

    usvh = u @ torch.diag(s) @ vh

    if len(m.shape)==4:
        usvh = usvh.reshape(m.shape[0], m.shape[1], m.shape[2], m.shape[3])

    return u, s, vh

def update_weight(m, u, s, vh, evol_dim_in, evol_dim_out, device):
    if len(m.shape)==4:
        step = m.shape[2]*m.shape[3]
    else:
        step = 1

    d_in = m.shape[1]
    d_out = m.shape[0]
    
    # contrôle de la taille des matrices
    # d_in : contrôle inutile car d_out contrôlé au layer précédent
    if d_out + evol_dim_out == 0:
        evol_dim_out = 0        
    if (d_in + evol_dim_in)*step < d_out + evol_dim_out:
        evol_dim_out = (d_in + evol_dim_in)*step - d_out
        
    # modif des poids
    if evol_dim_in < 0:
        vh = vh[:, :evol_dim_in*step]
    elif evol_dim_in > 0:
        vh_ = torch.randn(d_out, (d_in + evol_dim_in) * step, device=device)/(d_in + evol_dim_in)
        vh_[:d_out, :d_in*step] = vh
        vh = vh_
        
    if evol_dim_out < 0:
        u = u[:evol_dim_out, :evol_dim_out]
        s = s[:evol_dim_out]
        vh = vh[:evol_dim_out, :]
    elif evol_dim_out > 0:
        u_ = torch.randn(d_out + evol_dim_out, d_out + evol_dim_out, device=device)/(d_out + evol_dim_out)
        u_[:d_out, :d_out] = u
        u = u_
        s_ = torch.randn(d_out + evol_dim_out, device=device)/(d_out + evol_dim_out)
        s_[:d_out] = s      
        s = s_
        vh_ = torch.randn(d_out + evol_dim_out, (d_in + evol_dim_in) * step, device=device)/(d_in + evol_dim_in)
        vh_[:d_out, :(d_in + evol_dim_in) * step] = vh
        vh = vh_

    usvh = u @ torch.diag(s) @ vh

    if len(m.shape)==4:
        usvh = usvh.reshape(m.shape[0] + evol_dim_out, m.shape[1] + evol_dim_in, m.shape[2], m.shape[3])

    return usvh, evol_dim_in, evol_dim_out
    
def update_bias(bias, evol_dim_out, device):
    if evol_dim_out < 0:
        bias = bias[:evol_dim_out]
    elif evol_dim_out > 0:
        bias_ = torch.randn(bias.shape[0] + evol_dim_out, device=device)
        bias_[:bias.shape[0]] = bias
        bias = bias_
        
    return bias

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print('Using {} device'.format(device))

model_name = "20210729_MNIST_SVD"

layers_dict = {
    "ResBlock_0" : {"fun": ResBlock, "dims": [1,7,24]},
    "ResBlock_1" : {"fun": ResBlock, "dims": [24,48,72]},
    "DownscaleBlock_2" : {"fun": DownscaleBlock, "dims": []},
    "ResBlock_3" : {"fun": ResBlock, "dims": [72, 100, 120]},
    "ResBlock_4" : {"fun": ResBlock, "dims": [120, 140, 160]},
    "DownscaleBlock_5" : {"fun": DownscaleBlock, "dims": []},
    "ResBlock_6" : {"fun": ResBlock, "dims": [160, 180, 200]},
    "ResBlock_7" : {"fun": ResBlock, "dims": [200, 200, 200]},
    "DenseBlock_8" : {"fun": DenseBlock, "dims": [7*7*200, 10]},
    }
model = TestNN(layers_dict=layers_dict)
model.to(device)
print(model)

print(summary(model, input_size=X.shape, row_settings =("depth", "var_names"),depth=6))

train_losses = []
test_losses = []
# Out:
# Using cuda device
# TestNN(
#   (layers_dict): ModuleDict(
#     (ResBlock_0): ResBlock(
#       (layers_dict): ModuleDict(
#         (ResBlock_0_conv2d_0): Conv2d(1, 7, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (ResBlock_0_activation): LeakyReLU(negative_slope=0.2)
#         (ResBlock_0_conv2d_1): Conv2d(7, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#     )
#     (ResBlock_1): ResBlock(
#       (layers_dict): ModuleDict(
#         (ResBlock_1_conv2d_0): Conv2d(24, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (ResBlock_1_activation): LeakyReLU(negative_slope=0.2)
#         (ResBlock_1_conv2d_1): Conv2d(48, 72, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#     )
#     (DownscaleBlock_2): DownscaleBlock(
#       (layers_dict): ModuleDict(
#         (DownscaleBlock_2_MaxPool2d): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       )
#     )
#     (ResBlock_3): ResBlock(
#       (layers_dict): ModuleDict(
#         (ResBlock_3_conv2d_0): Conv2d(72, 100, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (ResBlock_3_activation): LeakyReLU(negative_slope=0.2)
#         (ResBlock_3_conv2d_1): Conv2d(100, 120, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#     )
#     (ResBlock_4): ResBlock(
#       (layers_dict): ModuleDict(
#         (ResBlock_4_conv2d_0): Conv2d(120, 140, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (ResBlock_4_activation): LeakyReLU(negative_slope=0.2)
#         (ResBlock_4_conv2d_1): Conv2d(140, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#     )
#     (DownscaleBlock_5): DownscaleBlock(
#       (layers_dict): ModuleDict(
#         (DownscaleBlock_5_MaxPool2d): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       )
#     )
#     (ResBlock_6): ResBlock(
#       (layers_dict): ModuleDict(
#         (ResBlock_6_conv2d_0): Conv2d(160, 180, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (ResBlock_6_activation): LeakyReLU(negative_slope=0.2)
#         (ResBlock_6_conv2d_1): Conv2d(180, 200, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#     )
#     (ResBlock_7): ResBlock(
#       (layers_dict): ModuleDict(
#         (ResBlock_7_conv2d_0): Conv2d(200, 200, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (ResBlock_7_activation): LeakyReLU(negative_slope=0.2)
#         (ResBlock_7_conv2d_1): Conv2d(200, 200, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#     )
#     (DenseBlock_8): DenseBlock(
#       (layers_dict): ModuleDict(
#         (DenseBlock_8_Flatten): Flatten(start_dim=1, end_dim=-1)
#         (DenseBlock_8_Dense): Linear(in_features=9800, out_features=10, bias=True)
#       )
#     )
#   )
# )
# ===================================================================================================================
# Layer (type (var_name):depth-idx)                                 Output Shape              Param #
# ===================================================================================================================
# TestNN                                                            --                        --
# ├─ModuleDict (layers_dict): 1                                     --                        --
# │    └─ResBlock (ResBlock_0): 2-1                                 [64, 24, 28, 28]          --
# │    │    └─ModuleDict (layers_dict): 3                           --                        --
# │    │    │    └─Conv2d (ResBlock_0_conv2d_0): 4-1                [64, 7, 28, 28]           70
# │    │    │    └─LeakyReLU (ResBlock_0_activation): 4-2           [64, 7, 28, 28]           --
# │    │    │    └─Conv2d (ResBlock_0_conv2d_1): 4-3                [64, 24, 28, 28]          1,536
# │    └─ResBlock (ResBlock_1): 2-2                                 [64, 72, 28, 28]          --
# │    │    └─ModuleDict (layers_dict): 3                           --                        --
# │    │    │    └─Conv2d (ResBlock_1_conv2d_0): 4-4                [64, 48, 28, 28]          10,416
# │    │    │    └─LeakyReLU (ResBlock_1_activation): 4-5           [64, 48, 28, 28]          --
# │    │    │    └─Conv2d (ResBlock_1_conv2d_1): 4-6                [64, 72, 28, 28]          31,176
# │    └─DownscaleBlock (DownscaleBlock_2): 2-3                     [64, 72, 14, 14]          --
# │    │    └─ModuleDict (layers_dict): 3                           --                        --
# │    │    │    └─MaxPool2d (DownscaleBlock_2_MaxPool2d): 4-7      [64, 72, 14, 14]          --
# │    └─ResBlock (ResBlock_3): 2-4                                 [64, 120, 14, 14]         --
# │    │    └─ModuleDict (layers_dict): 3                           --                        --
# │    │    │    └─Conv2d (ResBlock_3_conv2d_0): 4-8                [64, 100, 14, 14]         64,900
# │    │    │    └─LeakyReLU (ResBlock_3_activation): 4-9           [64, 100, 14, 14]         --
# │    │    │    └─Conv2d (ResBlock_3_conv2d_1): 4-10               [64, 120, 14, 14]         108,120
# │    └─ResBlock (ResBlock_4): 2-5                                 [64, 160, 14, 14]         --
# │    │    └─ModuleDict (layers_dict): 3                           --                        --
# │    │    │    └─Conv2d (ResBlock_4_conv2d_0): 4-11               [64, 140, 14, 14]         151,340
# │    │    │    └─LeakyReLU (ResBlock_4_activation): 4-12          [64, 140, 14, 14]         --
# │    │    │    └─Conv2d (ResBlock_4_conv2d_1): 4-13               [64, 160, 14, 14]         201,760
# │    └─DownscaleBlock (DownscaleBlock_5): 2-6                     [64, 160, 7, 7]           --
# │    │    └─ModuleDict (layers_dict): 3                           --                        --
# │    │    │    └─MaxPool2d (DownscaleBlock_5_MaxPool2d): 4-14     [64, 160, 7, 7]           --
# │    └─ResBlock (ResBlock_6): 2-7                                 [64, 200, 7, 7]           --
# │    │    └─ModuleDict (layers_dict): 3                           --                        --
# │    │    │    └─Conv2d (ResBlock_6_conv2d_0): 4-15               [64, 180, 7, 7]           259,380
# │    │    │    └─LeakyReLU (ResBlock_6_activation): 4-16          [64, 180, 7, 7]           --
# │    │    │    └─Conv2d (ResBlock_6_conv2d_1): 4-17               [64, 200, 7, 7]           324,200
# │    └─ResBlock (ResBlock_7): 2-8                                 [64, 200, 7, 7]           --
# │    │    └─ModuleDict (layers_dict): 3                           --                        --
# │    │    │    └─Conv2d (ResBlock_7_conv2d_0): 4-18               [64, 200, 7, 7]           360,200
# │    │    │    └─LeakyReLU (ResBlock_7_activation): 4-19          [64, 200, 7, 7]           --
# │    │    │    └─Conv2d (ResBlock_7_conv2d_1): 4-20               [64, 200, 7, 7]           360,200
# │    └─DenseBlock (DenseBlock_8): 2-9                             [64, 10]                  --
# │    │    └─ModuleDict (layers_dict): 3                           --                        --
# │    │    │    └─Flatten (DenseBlock_8_Flatten): 4-21             [64, 9800]                --
# │    │    │    └─Linear (DenseBlock_8_Dense): 4-22                [64, 10]                  98,010
# ===================================================================================================================
# Total params: 1,971,308
# Trainable params: 1,971,308
# Non-trainable params: 0
# Total mult-adds (G): 12.86
# ===================================================================================================================
# Input size (MB): 0.20
# Forward/backward pass size (MB): 132.37
# Params size (MB): 7.89
# Estimated Total Size (MB): 140.46
# ===================================================================================================================

# %%
nb_epochs = 10
prev_epoch = 100
optimizer = optim.SGD(model.parameters(), lr=1e-2, weight_decay=1e-2)
criterion = nn.NLLLoss()
try:
    len(test_losses)
    len(train_losses)
except:
    train_losses = []
    test_losses = []

model.to(device)
for epoch in range(nb_epochs):
    print(f"{datetime.now()} : Epoch : {epoch}")
    
    model.train()
    correct_train, target_count = 0, 0
    for x, y in train_dataloader:
        x, y = x.to(device), y.to(device)
        optimizer.zero_grad() # Clear gradients
        output = model(x) # Forward pass
        loss = criterion(output, y) # Calculate loss

        train_losses.append(loss.item())

        loss.backward() # Backward pass
        optimizer.step() # Optimize weights
        
        # accuracy
        _, predicted = torch.max(output.data, 1)
        target_count += y.size(0)
        correct_train += (y == predicted).sum().item()
    train_acc = (correct_train) / target_count
    print(f"training set accuracy : {train_acc}")
        
    model.eval()
    correct_train, target_count = 0, 0
    for x, y in test_dataloader:
        x, y = x.to(device), y.to(device)
        output = model(x) # Forward pass
        loss = criterion(output, y) # Calculate loss

        test_losses.append(loss.item())
        # accuracy
        _, predicted = torch.max(output.data, 1)
        target_count += y.size(0)
        correct_train += (y == predicted).sum().item()
    test_acc = (correct_train) / target_count
    print(f"testing set accuracy : {test_acc}")
    
    if (epoch + prev_epoch) % 2 == 1:
        print(datetime.now())
        print("optimizing layers...")    
        model = ModelsMgmt().optimize_layers(model, tresh_prun=5e-3, tresh_add=1e-2, flatten_size=7, device=device)
        iter = epoch + prev_epoch
        step = f"{iter}_iters_optim"
        ModelsMgmt().save(model, "D:\\Python\\DL_test\\DL_tests\\bckup", f"{model_name}_{step}")
        optimizer = optim.SGD(model.parameters(), lr=1e-2, weight_decay=1e-2)

print(summary(model, input_size=X.shape, row_settings =("depth", "var_names"),depth=6))

    
plt.figure()
plt.scatter([x for x in range(len(train_losses))], train_losses, s=2)
plt.show()

plt.figure()
plt.scatter([x for x in range(len(test_losses))], test_losses, s=2)
plt.show()
# Out:
# 2021-07-29 22:56:27.525765 : Epoch : 0
# training set accuracy : 0.988
# testing set accuracy : 0.9852
# 2021-07-29 22:56:54.023670 : Epoch : 1
# training set accuracy : 0.9872833333333333
# testing set accuracy : 0.9874
# 2021-07-29 22:57:20.836691
# optimizing layers...
# curr_layer : ResBlock_0_conv2d_0
# s : 0.0612044557929039...0.0018406923627480865, s.shape : torch.Size([3])
# s[-1]/energy : 0.024055471643805504
# augmenter d_out de 1
# weight.shape : torch.Size([4, 1, 3, 3])
# bias.shape : torch.Size([4])
# evol_dim_out : 1
# curr_layer : ResBlock_0_conv2d_1
# s : 0.07867541164159775...0.0003345362492837012, s.shape : torch.Size([4])
# augmenter d_in de 1
# s[-1]/energy : 0.004103615880012512
# réduire d_out de 1
# weight.shape : torch.Size([3, 4, 3, 3])
# bias.shape : torch.Size([3])
# evol_dim_out : -1
# curr_layer : ResBlock_1_conv2d_0
# s : 1.0830414295196533...0.021002979949116707, s.shape : torch.Size([7])
# réduire d_in de -1
# s[-1]/energy : 0.014712238684296608
# augmenter d_out de 1
# weight.shape : torch.Size([8, 3, 3, 3])
# bias.shape : torch.Size([8])
# evol_dim_out : 1
# curr_layer : ResBlock_1_conv2d_1
# s : 1.4001717567443848...0.02039044164121151, s.shape : torch.Size([9])
# augmenter d_in de 1
# s[-1]/energy : 0.009594243951141834
# weight.shape : torch.Size([9, 8, 3, 3])
# bias.shape : torch.Size([9])
# evol_dim_out : 0
# curr_layer : ResBlock_3_conv2d_0
# s : 0.8102347254753113...0.013253698125481606, s.shape : torch.Size([4])
# s[-1]/energy : 0.008338681422173977
# curr_layer : ResBlock_3_conv2d_1
# s : 0.88446444272995...0.017245827242732048, s.shape : torch.Size([12])
# s[-1]/energy : 0.007923307828605175
# curr_layer : ResBlock_4_conv2d_0
# s : 0.8086856603622437...0.02610117755830288, s.shape : torch.Size([7])
# s[-1]/energy : 0.009561752900481224
# curr_layer : ResBlock_4_conv2d_1
# s : 0.6455796957015991...0.03410926088690758, s.shape : torch.Size([14])
# s[-1]/energy : 0.007751184981316328
# curr_layer : ResBlock_6_conv2d_0
# s : 0.32153940200805664...0.008563872426748276, s.shape : torch.Size([9])
# s[-1]/energy : 0.007634453475475311
# curr_layer : ResBlock_6_conv2d_1
# s : 0.35552698373794556...0.012010314501821995, s.shape : torch.Size([13])
# s[-1]/energy : 0.010056311264634132
# augmenter d_out de 1
# weight.shape : torch.Size([14, 9, 3, 3])
# bias.shape : torch.Size([14])
# evol_dim_out : 1
# curr_layer : ResBlock_7_conv2d_0
# s : 0.4126877784729004...0.006854585837572813, s.shape : torch.Size([8])
# augmenter d_in de 1
# s[-1]/energy : 0.007482221815735102
# weight.shape : torch.Size([8, 14, 3, 3])
# bias.shape : torch.Size([8])
# evol_dim_out : 0
# curr_layer : ResBlock_7_conv2d_1
# s : 0.37269121408462524...0.009956811554729939, s.shape : torch.Size([13])
# s[-1]/energy : 0.008204923011362553
# curr_layer : DenseBlock_8_Dense
# s : 0.7412072420120239...1.9505354430293664e-05, s.shape : torch.Size([10])
# s[-1]/energy : 3.7326990423025563e-06
# layers_dict_in : {'ResBlock_0': {'fun': <class '__main__.ResBlock'>, 'dims': [1, 4, 3]}, 'ResBlock_1': {'fun': <class '__main__.ResBlock'>, 'dims': [3, 8, 9]}, 'DownscaleBlock_2': {'fun': <class '__main__.DownscaleBlock'>, 'dims': []}, 'ResBlock_3': {'fun': <class '__main__.ResBlock'>, 'dims': [9, 4, 12]}, 'ResBlock_4': {'fun': <class '__main__.ResBlock'>, 'dims': [12, 7, 14]}, 'DownscaleBlock_5': {'fun': <class '__main__.DownscaleBlock'>, 'dims': []}, 'ResBlock_6': {'fun': <class '__main__.ResBlock'>, 'dims': [14, 9, 14]}, 'ResBlock_7': {'fun': <class '__main__.ResBlock'>, 'dims': [14, 8, 13]}, 'DenseBlock_8': {'fun': <class '__main__.DenseBlock'>, 'dims': [637, 10]}}
# 2021-07-29 22:57:21.284553 : Epoch : 2
# training set accuracy : 0.9881
# testing set accuracy : 0.9868
# 2021-07-29 22:57:47.605740 : Epoch : 3
# training set accuracy : 0.9876666666666667
# testing set accuracy : 0.9852
# 2021-07-29 22:58:13.711700
# optimizing layers...
# curr_layer : ResBlock_0_conv2d_0
# s : 0.20703499019145966...0.0014879259979352355, s.shape : torch.Size([4])
# s[-1]/energy : 0.005223590414971113
# curr_layer : ResBlock_0_conv2d_1
# s : 0.12196200340986252...0.001980219502002001, s.shape : torch.Size([3])
# s[-1]/energy : 0.01564866304397583
# augmenter d_out de 1
# weight.shape : torch.Size([4, 4, 3, 3])
# bias.shape : torch.Size([4])
# evol_dim_out : 1
# curr_layer : ResBlock_1_conv2d_0
# s : 1.0329668521881104...0.005686180200427771, s.shape : torch.Size([8])
# augmenter d_in de 1
# s[-1]/energy : 0.004273685626685619
# réduire d_out de 1
# weight.shape : torch.Size([7, 4, 3, 3])
# bias.shape : torch.Size([7])
# evol_dim_out : -1
# curr_layer : ResBlock_1_conv2d_1
# s : 1.4087879657745361...0.02004667930305004, s.shape : torch.Size([9])
# réduire d_in de -1
# s[-1]/energy : 0.009470833465456963
# weight.shape : torch.Size([9, 7, 3, 3])
# bias.shape : torch.Size([9])
# evol_dim_out : 0
# curr_layer : ResBlock_3_conv2d_0
# s : 0.8229377269744873...0.012497063726186752, s.shape : torch.Size([4])
# s[-1]/energy : 0.007748270872980356
# curr_layer : ResBlock_3_conv2d_1
# s : 0.9143965840339661...0.0165006872266531, s.shape : torch.Size([12])
# s[-1]/energy : 0.007392311468720436
# curr_layer : ResBlock_4_conv2d_0
# s : 0.8192018270492554...0.027702972292900085, s.shape : torch.Size([7])
# s[-1]/energy : 0.010019874200224876
# augmenter d_out de 1
# weight.shape : torch.Size([8, 12, 3, 3])
# bias.shape : torch.Size([8])
# evol_dim_out : 1
# curr_layer : ResBlock_4_conv2d_1
# s : 0.652306318283081...0.036204829812049866, s.shape : torch.Size([14])
# augmenter d_in de 1
# s[-1]/energy : 0.008149809204041958
# weight.shape : torch.Size([14, 8, 3, 3])
# bias.shape : torch.Size([14])
# evol_dim_out : 0
# curr_layer : ResBlock_6_conv2d_0
# s : 0.32813549041748047...0.00827063899487257, s.shape : torch.Size([9])
# s[-1]/energy : 0.007207510527223349
# curr_layer : ResBlock_6_conv2d_1
# s : 0.3562503755092621...0.003905525431036949, s.shape : torch.Size([14])
# s[-1]/energy : 0.003210019553080201
# réduire d_out de 1
# weight.shape : torch.Size([13, 9, 3, 3])
# bias.shape : torch.Size([13])
# evol_dim_out : -1
# curr_layer : ResBlock_7_conv2d_0
# s : 0.4161871075630188...0.006502102129161358, s.shape : torch.Size([8])
# réduire d_in de -1
# s[-1]/energy : 0.006966688204556704
# weight.shape : torch.Size([8, 13, 3, 3])
# bias.shape : torch.Size([8])
# evol_dim_out : 0
# curr_layer : ResBlock_7_conv2d_1
# s : 0.37171393632888794...0.010057895444333553, s.shape : torch.Size([13])
# s[-1]/energy : 0.008290635421872139
# curr_layer : DenseBlock_8_Dense
# s : 0.7414385080337524...1.8692007870413363e-05, s.shape : torch.Size([10])
# s[-1]/energy : 3.567336079868255e-06
# layers_dict_in : {'ResBlock_0': {'fun': <class '__main__.ResBlock'>, 'dims': [1, 4, 4]}, 'ResBlock_1': {'fun': <class '__main__.ResBlock'>, 'dims': [4, 7, 9]}, 'DownscaleBlock_2': {'fun': <class '__main__.DownscaleBlock'>, 'dims': []}, 'ResBlock_3': {'fun': <class '__main__.ResBlock'>, 'dims': [9, 4, 12]}, 'ResBlock_4': {'fun': <class '__main__.ResBlock'>, 'dims': [12, 8, 14]}, 'DownscaleBlock_5': {'fun': <class '__main__.DownscaleBlock'>, 'dims': []}, 'ResBlock_6': {'fun': <class '__main__.ResBlock'>, 'dims': [14, 9, 13]}, 'ResBlock_7': {'fun': <class '__main__.ResBlock'>, 'dims': [13, 8, 13]}, 'DenseBlock_8': {'fun': <class '__main__.DenseBlock'>, 'dims': [637, 10]}}
# 2021-07-29 22:58:14.171471 : Epoch : 4
# training set accuracy : 0.9876833333333334
# testing set accuracy : 0.9862
# 2021-07-29 22:58:41.198599 : Epoch : 5
# training set accuracy : 0.9876166666666667
# testing set accuracy : 0.9856
# 2021-07-29 22:59:08.485032
# optimizing layers...
# curr_layer : ResBlock_0_conv2d_0
# s : 0.2378203272819519...0.0036274874582886696, s.shape : torch.Size([4])
# s[-1]/energy : 0.011415124870836735
# augmenter d_out de 1
# weight.shape : torch.Size([5, 1, 3, 3])
# bias.shape : torch.Size([5])
# evol_dim_out : 1
# curr_layer : ResBlock_0_conv2d_1
# s : 0.2172548621892929...0.0024000725243240595, s.shape : torch.Size([4])
# augmenter d_in de 1
# s[-1]/energy : 0.008941500447690487
# weight.shape : torch.Size([4, 5, 3, 3])
# bias.shape : torch.Size([4])
# evol_dim_out : 0
# curr_layer : ResBlock_1_conv2d_0
# s : 1.1181018352508545...0.017563890665769577, s.shape : torch.Size([7])
# s[-1]/energy : 0.012197413481771946
# augmenter d_out de 1
# weight.shape : torch.Size([8, 4, 3, 3])
# bias.shape : torch.Size([8])
# evol_dim_out : 1
# curr_layer : ResBlock_1_conv2d_1
# s : 1.2586803436279297...0.017352214083075523, s.shape : torch.Size([9])
# augmenter d_in de 1
# s[-1]/energy : 0.009224826470017433
# weight.shape : torch.Size([9, 8, 3, 3])
# bias.shape : torch.Size([9])
# evol_dim_out : 0
# curr_layer : ResBlock_3_conv2d_0
# s : 0.8099590539932251...0.011840207502245903, s.shape : torch.Size([4])
# s[-1]/energy : 0.007454931270331144
# curr_layer : ResBlock_3_conv2d_1
# s : 0.9099053144454956...0.015664178878068924, s.shape : torch.Size([12])
# s[-1]/energy : 0.007047634106129408
# curr_layer : ResBlock_4_conv2d_0
# s : 0.8083444237709045...0.024180633947253227, s.shape : torch.Size([8])
# s[-1]/energy : 0.008720257319509983
# curr_layer : ResBlock_4_conv2d_1
# s : 0.6845895648002625...0.03861314058303833, s.shape : torch.Size([14])
# s[-1]/energy : 0.008302008733153343
# curr_layer : ResBlock_6_conv2d_0
# s : 0.3335006833076477...0.007856647484004498, s.shape : torch.Size([9])
# s[-1]/energy : 0.0067547899670898914
# curr_layer : ResBlock_6_conv2d_1
# s : 0.35482892394065857...0.01312923338264227, s.shape : torch.Size([13])
# s[-1]/energy : 0.010761835612356663
# augmenter d_out de 1
# weight.shape : torch.Size([14, 9, 3, 3])
# bias.shape : torch.Size([14])
# evol_dim_out : 1
# curr_layer : ResBlock_7_conv2d_0
# s : 0.4128124415874481...0.0053222631104290485, s.shape : torch.Size([8])
# augmenter d_in de 1
# s[-1]/energy : 0.005804805550724268
# weight.shape : torch.Size([8, 14, 3, 3])
# bias.shape : torch.Size([8])
# evol_dim_out : 0
# curr_layer : ResBlock_7_conv2d_1
# s : 0.3659511208534241...0.009860427118837833, s.shape : torch.Size([13])
# s[-1]/energy : 0.008145852014422417
# curr_layer : DenseBlock_8_Dense
# s : 0.7394082546234131...1.827110281737987e-05, s.shape : torch.Size([10])
# s[-1]/energy : 3.5122068311466137e-06
# layers_dict_in : {'ResBlock_0': {'fun': <class '__main__.ResBlock'>, 'dims': [1, 5, 4]}, 'ResBlock_1': {'fun': <class '__main__.ResBlock'>, 'dims': [4, 8, 9]}, 'DownscaleBlock_2': {'fun': <class '__main__.DownscaleBlock'>, 'dims': []}, 'ResBlock_3': {'fun': <class '__main__.ResBlock'>, 'dims': [9, 4, 12]}, 'ResBlock_4': {'fun': <class '__main__.ResBlock'>, 'dims': [12, 8, 14]}, 'DownscaleBlock_5': {'fun': <class '__main__.DownscaleBlock'>, 'dims': []}, 'ResBlock_6': {'fun': <class '__main__.ResBlock'>, 'dims': [14, 9, 14]}, 'ResBlock_7': {'fun': <class '__main__.ResBlock'>, 'dims': [14, 8, 13]}, 'DenseBlock_8': {'fun': <class '__main__.DenseBlock'>, 'dims': [637, 10]}}
# 2021-07-29 22:59:08.937822 : Epoch : 6
# training set accuracy : 0.9879666666666667
# testing set accuracy : 0.9865
# 2021-07-29 22:59:35.331014 : Epoch : 7
# training set accuracy : 0.9874666666666667
# testing set accuracy : 0.9858
# 2021-07-29 23:00:01.070043
# optimizing layers...
# curr_layer : ResBlock_0_conv2d_0
# s : 0.36290815472602844...0.004434023983776569, s.shape : torch.Size([5])
# s[-1]/energy : 0.007704151328653097
# curr_layer : ResBlock_0_conv2d_1
# s : 0.32608142495155334...0.004858203232288361, s.shape : torch.Size([4])
# s[-1]/energy : 0.012513197958469391
# augmenter d_out de 1
# weight.shape : torch.Size([5, 5, 3, 3])
# bias.shape : torch.Size([5])
# evol_dim_out : 1
# curr_layer : ResBlock_1_conv2d_0
# s : 1.0937131643295288...0.015480512753129005, s.shape : torch.Size([8])
# augmenter d_in de 1
# s[-1]/energy : 0.010989791713654995
# augmenter d_out de 1
# weight.shape : torch.Size([9, 5, 3, 3])
# bias.shape : torch.Size([9])
# evol_dim_out : 1
# curr_layer : ResBlock_1_conv2d_1
# s : 1.2715116739273071...0.01636897400021553, s.shape : torch.Size([9])
# augmenter d_in de 1
# s[-1]/energy : 0.008718281053006649
# weight.shape : torch.Size([9, 9, 3, 3])
# bias.shape : torch.Size([9])
# evol_dim_out : 0
# curr_layer : ResBlock_3_conv2d_0
# s : 0.7791606187820435...0.011647808365523815, s.shape : torch.Size([4])
# s[-1]/energy : 0.007561699952930212
# curr_layer : ResBlock_3_conv2d_1
# s : 0.8903123736381531...0.015555580146610737, s.shape : torch.Size([12])
# s[-1]/energy : 0.007118211127817631
# curr_layer : ResBlock_4_conv2d_0
# s : 0.7920352816581726...0.023680321872234344, s.shape : torch.Size([8])
# s[-1]/energy : 0.008702347055077553
# curr_layer : ResBlock_4_conv2d_1
# s : 0.6606226563453674...0.035470522940158844, s.shape : torch.Size([14])
# s[-1]/energy : 0.007844571024179459
# curr_layer : ResBlock_6_conv2d_0
# s : 0.3272559940814972...0.007925871759653091, s.shape : torch.Size([9])
# s[-1]/energy : 0.006873416248708963
# curr_layer : ResBlock_6_conv2d_1
# s : 0.3459569811820984...0.002209785860031843, s.shape : torch.Size([14])
# s[-1]/energy : 0.001812671427614987
# réduire d_out de 1
# weight.shape : torch.Size([13, 9, 3, 3])
# bias.shape : torch.Size([13])
# evol_dim_out : -1
# curr_layer : ResBlock_7_conv2d_0
# s : 0.4060865342617035...0.004918097052723169, s.shape : torch.Size([8])
# réduire d_in de -1
# s[-1]/energy : 0.005413705948740244
# weight.shape : torch.Size([8, 13, 3, 3])
# bias.shape : torch.Size([8])
# evol_dim_out : 0
# curr_layer : ResBlock_7_conv2d_1
# s : 0.3574206233024597...0.010010515339672565, s.shape : torch.Size([13])
# s[-1]/energy : 0.008441447280347347
# curr_layer : DenseBlock_8_Dense
# s : 0.7287853956222534...1.8162196283810772e-05, s.shape : torch.Size([10])
# s[-1]/energy : 3.5178131838620175e-06
# layers_dict_in : {'ResBlock_0': {'fun': <class '__main__.ResBlock'>, 'dims': [1, 5, 5]}, 'ResBlock_1': {'fun': <class '__main__.ResBlock'>, 'dims': [5, 9, 9]}, 'DownscaleBlock_2': {'fun': <class '__main__.DownscaleBlock'>, 'dims': []}, 'ResBlock_3': {'fun': <class '__main__.ResBlock'>, 'dims': [9, 4, 12]}, 'ResBlock_4': {'fun': <class '__main__.ResBlock'>, 'dims': [12, 8, 14]}, 'DownscaleBlock_5': {'fun': <class '__main__.DownscaleBlock'>, 'dims': []}, 'ResBlock_6': {'fun': <class '__main__.ResBlock'>, 'dims': [14, 9, 13]}, 'ResBlock_7': {'fun': <class '__main__.ResBlock'>, 'dims': [13, 8, 13]}, 'DenseBlock_8': {'fun': <class '__main__.DenseBlock'>, 'dims': [637, 10]}}
# 2021-07-29 23:00:01.531809 : Epoch : 8
# training set accuracy : 0.9874666666666667
# testing set accuracy : 0.9859
# 2021-07-29 23:00:28.015749 : Epoch : 9
# training set accuracy : 0.9879333333333333
# testing set accuracy : 0.9803
# 2021-07-29 23:00:54.544193
# optimizing layers...
# curr_layer : ResBlock_0_conv2d_0
# s : 0.4124530255794525...0.004751759115606546, s.shape : torch.Size([5])
# s[-1]/energy : 0.007952876389026642
# curr_layer : ResBlock_0_conv2d_1
# s : 0.3925260901451111...0.004793194122612476, s.shape : torch.Size([5])
# s[-1]/energy : 0.010148522444069386
# augmenter d_out de 1
# weight.shape : torch.Size([6, 5, 3, 3])
# bias.shape : torch.Size([6])
# evol_dim_out : 1
# curr_layer : ResBlock_1_conv2d_0
# s : 1.1583476066589355...0.01330634206533432, s.shape : torch.Size([9])
# augmenter d_in de 1
# s[-1]/energy : 0.008649598807096481
# weight.shape : torch.Size([9, 6, 3, 3])
# bias.shape : torch.Size([9])
# evol_dim_out : 0
# curr_layer : ResBlock_1_conv2d_1
# s : 1.2189993858337402...0.01606929861009121, s.shape : torch.Size([9])
# s[-1]/energy : 0.0088259968906641
# curr_layer : ResBlock_3_conv2d_0
# s : 0.7555770874023438...0.01203351840376854, s.shape : torch.Size([4])
# s[-1]/energy : 0.007978010922670364
# curr_layer : ResBlock_3_conv2d_1
# s : 0.8753628730773926...0.01656218431890011, s.shape : torch.Size([12])
# s[-1]/energy : 0.007641172036528587
# curr_layer : ResBlock_4_conv2d_0
# s : 0.781405508518219...0.02518991380929947, s.shape : torch.Size([8])
# s[-1]/energy : 0.00940932147204876
# curr_layer : ResBlock_4_conv2d_1
# s : 0.6461916565895081...0.0357976071536541, s.shape : torch.Size([14])
# s[-1]/energy : 0.008073518984019756
# curr_layer : ResBlock_6_conv2d_0
# s : 0.3305571973323822...0.007199850399047136, s.shape : torch.Size([9])
# s[-1]/energy : 0.0062544201500713825
# curr_layer : ResBlock_6_conv2d_1
# s : 0.34293806552886963...0.014399559237062931, s.shape : torch.Size([13])
# s[-1]/energy : 0.011893898248672485
# augmenter d_out de 1
# weight.shape : torch.Size([14, 9, 3, 3])
# bias.shape : torch.Size([14])
# evol_dim_out : 1
# curr_layer : ResBlock_7_conv2d_0
# s : 0.40410906076431274...0.004284663591533899, s.shape : torch.Size([8])
# augmenter d_in de 1
# s[-1]/energy : 0.004804534837603569
# réduire d_out de 1
# weight.shape : torch.Size([7, 14, 3, 3])
# bias.shape : torch.Size([7])
# evol_dim_out : -1
# curr_layer : ResBlock_7_conv2d_1
# s : 0.35502806305885315...0.00991819892078638, s.shape : torch.Size([13])
# réduire d_in de -1
# s[-1]/energy : 0.008371763862669468
# weight.shape : torch.Size([13, 7, 3, 3])
# bias.shape : torch.Size([13])
# evol_dim_out : 0
# curr_layer : DenseBlock_8_Dense
# s : 0.7262759804725647...1.8290549633093178e-05, s.shape : torch.Size([10])
# s[-1]/energy : 3.555155444701086e-06
# layers_dict_in : {'ResBlock_0': {'fun': <class '__main__.ResBlock'>, 'dims': [1, 5, 6]}, 'ResBlock_1': {'fun': <class '__main__.ResBlock'>, 'dims': [6, 9, 9]}, 'DownscaleBlock_2': {'fun': <class '__main__.DownscaleBlock'>, 'dims': []}, 'ResBlock_3': {'fun': <class '__main__.ResBlock'>, 'dims': [9, 4, 12]}, 'ResBlock_4': {'fun': <class '__main__.ResBlock'>, 'dims': [12, 8, 14]}, 'DownscaleBlock_5': {'fun': <class '__main__.DownscaleBlock'>, 'dims': []}, 'ResBlock_6': {'fun': <class '__main__.ResBlock'>, 'dims': [14, 9, 14]}, 'ResBlock_7': {'fun': <class '__main__.ResBlock'>, 'dims': [14, 7, 13]}, 'DenseBlock_8': {'fun': <class '__main__.DenseBlock'>, 'dims': [637, 10]}}
# ===================================================================================================================
# Layer (type (var_name):depth-idx)                                 Output Shape              Param #
# ===================================================================================================================
# TestNN                                                            --                        --
# ├─ModuleDict (layers_dict): 1                                     --                        --
# │    └─ResBlock (ResBlock_0): 2-1                                 [64, 6, 28, 28]           --
# │    │    └─ModuleDict (layers_dict): 3                           --                        --
# │    │    │    └─Conv2d (ResBlock_0_conv2d_0): 4-1                [64, 5, 28, 28]           50
# │    │    │    └─LeakyReLU (ResBlock_0_activation): 4-2           [64, 5, 28, 28]           --
# │    │    │    └─Conv2d (ResBlock_0_conv2d_1): 4-3                [64, 6, 28, 28]           276
# │    └─ResBlock (ResBlock_1): 2-2                                 [64, 9, 28, 28]           --
# │    │    └─ModuleDict (layers_dict): 3                           --                        --
# │    │    │    └─Conv2d (ResBlock_1_conv2d_0): 4-4                [64, 9, 28, 28]           495
# │    │    │    └─LeakyReLU (ResBlock_1_activation): 4-5           [64, 9, 28, 28]           --
# │    │    │    └─Conv2d (ResBlock_1_conv2d_1): 4-6                [64, 9, 28, 28]           738
# │    └─DownscaleBlock (DownscaleBlock_2): 2-3                     [64, 9, 14, 14]           --
# │    │    └─ModuleDict (layers_dict): 3                           --                        --
# │    │    │    └─MaxPool2d (DownscaleBlock_2_MaxPool2d): 4-7      [64, 9, 14, 14]           --
# │    └─ResBlock (ResBlock_3): 2-4                                 [64, 12, 14, 14]          --
# │    │    └─ModuleDict (layers_dict): 3                           --                        --
# │    │    │    └─Conv2d (ResBlock_3_conv2d_0): 4-8                [64, 4, 14, 14]           328
# │    │    │    └─LeakyReLU (ResBlock_3_activation): 4-9           [64, 4, 14, 14]           --
# │    │    │    └─Conv2d (ResBlock_3_conv2d_1): 4-10               [64, 12, 14, 14]          444
# │    └─ResBlock (ResBlock_4): 2-5                                 [64, 14, 14, 14]          --
# │    │    └─ModuleDict (layers_dict): 3                           --                        --
# │    │    │    └─Conv2d (ResBlock_4_conv2d_0): 4-11               [64, 8, 14, 14]           872
# │    │    │    └─LeakyReLU (ResBlock_4_activation): 4-12          [64, 8, 14, 14]           --
# │    │    │    └─Conv2d (ResBlock_4_conv2d_1): 4-13               [64, 14, 14, 14]          1,022
# │    └─DownscaleBlock (DownscaleBlock_5): 2-6                     [64, 14, 7, 7]            --
# │    │    └─ModuleDict (layers_dict): 3                           --                        --
# │    │    │    └─MaxPool2d (DownscaleBlock_5_MaxPool2d): 4-14     [64, 14, 7, 7]            --
# │    └─ResBlock (ResBlock_6): 2-7                                 [64, 14, 7, 7]            --
# │    │    └─ModuleDict (layers_dict): 3                           --                        --
# │    │    │    └─Conv2d (ResBlock_6_conv2d_0): 4-15               [64, 9, 7, 7]             1,143
# │    │    │    └─LeakyReLU (ResBlock_6_activation): 4-16          [64, 9, 7, 7]             --
# │    │    │    └─Conv2d (ResBlock_6_conv2d_1): 4-17               [64, 14, 7, 7]            1,148
# │    └─ResBlock (ResBlock_7): 2-8                                 [64, 13, 7, 7]            --
# │    │    └─ModuleDict (layers_dict): 3                           --                        --
# │    │    │    └─Conv2d (ResBlock_7_conv2d_0): 4-18               [64, 7, 7, 7]             889
# │    │    │    └─LeakyReLU (ResBlock_7_activation): 4-19          [64, 7, 7, 7]             --
# │    │    │    └─Conv2d (ResBlock_7_conv2d_1): 4-20               [64, 13, 7, 7]            832
# │    └─DenseBlock (DenseBlock_8): 2-9                             [64, 10]                  --
# │    │    └─ModuleDict (layers_dict): 3                           --                        --
# │    │    │    └─Flatten (DenseBlock_8_Flatten): 4-21             [64, 637]                 --
# │    │    │    └─Linear (DenseBlock_8_Dense): 4-22                [64, 10]                  6,380
# ===================================================================================================================
# Total params: 14,617
# Trainable params: 14,617
# Non-trainable params: 0
# Total mult-adds (M): 124.66
# ===================================================================================================================
# Input size (MB): 0.20
# Forward/backward pass size (MB): 16.54
# Params size (MB): 0.06
# Estimated Total Size (MB): 16.80
# ===================================================================================================================

# %%
# Récupérer un backup
print(datetime.now())
ModelsMgmt().optimize_layers(model, tresh_prun=6e-3, tresh_add=1.8e-2, flatten_size=7, device=device)
print(summary(model, input_size=X.shape, row_settings =("depth", "var_names"),depth=6))


generic_name = "20210729_MNIST_SVD"
step = "71_iters_optim"

ModelsMgmt().load(model, device, "D:\\Python\\DL_test\\DL_tests\\bckup", f"{generic_name}_{step}")

# %%
print(f"Using {device} device")
# Out:
# Using cuda device

# %%
# %whos
# Out:
# Variable           Type          Data/Info
# ------------------------------------------
# DataLoader         type          <class 'torch.utils.data.dataloader.DataLoader'>
# DenseBlock         type          <class '__main__.DenseBlock'>
# DownscaleBlock     type          <class '__main__.DownscaleBlock'>
# F                  module        <module 'torch.nn.functio<...>orch\\nn\\functional.py'>
# ModelsMgmt         type          <class '__main__.ModelsMgmt'>
# ResBlock           type          <class '__main__.ResBlock'>
# TestNN             type          <class '__main__.TestNN'>
# ToTensor           type          <class 'torchvision.trans<...>rms.transforms.ToTensor'>
# X                  Tensor        tensor([[[[0., 0., 0.,  .<...>0.,  ..., 0., 0., 0.]]]])
# batch_size         int           64
# correct_train      int           9839
# criterion          NLLLoss       NLLLoss()
# dataset_path       str           D:\Python\DL_test\datasets
# datasets           module        <module 'torchvision.data<...>\\datasets\\__init__.py'>
# datetime           type          <class 'datetime.datetime'>
# device             str           cuda
# epoch              int           4
# generic_name       str           20210727_toy_model
# get_usvh           function      <function get_usvh at 0x00000267C7A6CE50>
# layers_dict        dict          n=9
# loss               Tensor        tensor(0.0009, device='cu<...>rad_fn=<NllLossBackward>)
# model              TestNN        TestNN(\n  (layers_dict):<...>)\n      )\n    )\n  )\n)
# nb_epochs          int           5
# nn                 module        <module 'torch.nn' from '<...>\torch\\nn\\__init__.py'>
# np                 module        <module 'numpy' from 'C:\<...>ges\\numpy\\__init__.py'>
# optim              module        <module 'torch.optim' fro<...>rch\\optim\\__init__.py'>
# optimizer          SGD           SGD (\nParameter Group 0\<...>    weight_decay: 0.01\n)
# os                 module        <module 'os' from 'C:\\Us<...>vs\\dl_test\\lib\\os.py'>
# output             Tensor        tensor([[-1.2732e+01, -4.<...>_fn=<LogSoftmaxBackward>)
# param              Parameter     Parameter containing:\nte<...>a:0', requires_grad=True)
# pd                 module        <module 'pandas' from 'C:<...>es\\pandas\\__init__.py'>
# pickle             module        <module 'pickle' from 'C:<...>dl_test\\lib\\pickle.py'>
# plt                module        <module 'matplotlib.pyplo<...>\\matplotlib\\pyplot.py'>
# predicted          Tensor        tensor([1, 2, 3, 4, 5, 6,<...>, 5, 6], device='cuda:0')
# save               bool          True
# step               str           5_iters_2_optim
# summary            function      <function summary at 0x0000026795605D30>
# target_count       int           10000
# test_acc           float         0.9839
# test_data          MNIST         Dataset MNIST\n    Number<...>rm\nTransform: ToTensor()
# test_dataloader    DataLoader    <torch.utils.data.dataloa<...>ct at 0x0000026795617B50>
# test_losses        list          n=1413
# torch              module        <module 'torch' from 'C:\<...>ges\\torch\\__init__.py'>
# train_acc          float         0.9873666666666666
# train_dataloader   DataLoader    <torch.utils.data.dataloa<...>ct at 0x0000026795617B20>
# train_losses       list          n=8442
# training_data      MNIST         Dataset MNIST\n    Number<...>rm\nTransform: ToTensor()
# update_bias        function      <function update_bias at 0x0000026795625700>
# update_weight      function      <function update_weight at 0x0000026798B17A60>
# x                  Tensor        tensor([[[[0., 0., 0.,  .<...> 0.]]]], device='cuda:0')
# y                  Tensor        tensor([1, 2, 3, 4, 5, 6,<...>, 5, 6], device='cuda:0')
